# %%
import requests
url = "https://i.guim.co.uk/img/media/327aa3f0c3b8e40ab03b4ae80319064e401c6fbc/377_133_3542_2834/master/3542.jpg?width=1200&height=1200&quality=85&auto=format&fit=crop&s=34d32522f47e4a67286f9894fc81c863"
response = requests.get(url)
with open ("image.jpg", "wb") as f: # wb means write binary
    f.write(response.content) # write the content of the response to the file
print("Image downloaded successfully!")
import cv2
import os 
os.chdir(r"D:\AI\1. Courses\2. Computer Vision\Codes\1. Computer vision")
img = cv2.imread("image.jpg")
img=cv2.resize(img, (400, 400)) # resize the image to 400x400
cv2.imshow("Image", img)
cv2.waitKey(0) # wait until a key is pressed
cv2.destroyAllWindows()
# Out:
# Image downloaded successfully!

# %% [markdown]
# # To show Color map at Opencv library

# %%
maps = [attr for attr in dir(cv2) if "COLORMAP" in attr]
print(maps)
# Out:
# ['COLORMAP_AUTUMN', 'COLORMAP_BONE', 'COLORMAP_CIVIDIS', 'COLORMAP_COOL', 'COLORMAP_DEEPGREEN', 'COLORMAP_HOT', 'COLORMAP_HSV', 'COLORMAP_INFERNO', 'COLORMAP_JET', 'COLORMAP_MAGMA', 'COLORMAP_OCEAN', 'COLORMAP_PARULA', 'COLORMAP_PINK', 'COLORMAP_PLASMA', 'COLORMAP_RAINBOW', 'COLORMAP_SPRING', 'COLORMAP_SUMMER', 'COLORMAP_TURBO', 'COLORMAP_TWILIGHT', 'COLORMAP_TWILIGHT_SHIFTED', 'COLORMAP_VIRIDIS', 'COLORMAP_WINTER']

# %% [markdown]
# # To Show Color map for Images

# %%
import cv2 
import matplotlib.pyplot as plt
img_bgr = cv2.imread("image.jpg")
# Convert the image from BGR to RGB color space
img_rgb = cv2.cvtColor(img_bgr,cv2.COLOR_BGR2RGB)
img_gray = cv2.cvtColor(img_rgb, cv2.COLOR_RGB2GRAY)
#Create a figure 
plt.figure(figsize=(10, 10))
# Show the original image
plt.subplot(1, 3, 1)
plt.imshow(img_rgb)
plt.title("Original Image")
plt.axis("off")
# Show the RGB image
plt.subplot(1, 3, 2)
plt.imshow(img_rgb)
plt.title("RGB Image")
plt.axis("off")
# Show the grayscale image
plt.subplot(1, 3, 3)
plt.imshow(img_gray, cmap="gray")
plt.title("Grayscale Image")
plt.axis("off")
plt.show()

# %% [markdown]
# # Traditional CV Pipeline

# %%
import cv2
import matplotlib.pyplot as plt
img_bgr = cv2.imread("image.jpg")
# Convert the image from BGR to RGB color space
img_rgb = cv2.cvtColor(img_bgr,cv2.COLOR_BGR2RGB)
img_gray = cv2.cvtColor(img_rgb, cv2.COLOR_RGB2GRAY)
# Adaptive thresholding
img_adaptive_thresh = cv2.adaptiveThreshold(img_gray,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY_INV,19,20)
#Canny edge detection
img_canny = cv2.Canny(img_gray, 100, 200)
#Dilate the edges
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3))
img_dilated = cv2.dilate(img_canny, kernel, iterations=2)
#Create a figure
plt.figure(figsize=(10, 10))
# Show the original image
plt.subplot(1, 4, 1)
plt.imshow(img_rgb)
plt.title("Original Image")
plt.axis("off")
# Show the adaptive thresholding image
plt.subplot(1, 4, 2)
plt.imshow(img_adaptive_thresh, cmap="gray")
plt.title("Adaptive Thresholding")
plt.axis("off")
# Show the Canny edge detection image
plt.subplot(1, 4, 3)
plt.imshow(img_canny, cmap="gray")
plt.title("Canny Edge Detection")
plt.axis("off")
# Show the dilated edges image
plt.subplot(1, 4, 4)
plt.imshow(img_dilated, cmap="gray")
plt.title("Dilated Edges")
plt.axis("off")
plt.show()

# %%
img_bgr = cv2.imread("image.jpg")
# Convert the image from BGR to RGB color space
img_rgb = cv2.cvtColor(img_bgr,cv2.COLOR_BGR2RGB)
img_gray = cv2.cvtColor(img_rgb, cv2.COLOR_RGB2GRAY)
# Adaptive thresholding
img_adaptive_thresh = cv2.adaptiveThreshold(img_gray,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY_INV,19,20)
edges = cv2.Canny(img_adaptive_thresh,100,200)
plt.imshow(img_adaptive_thresh, cmap='gray')
kernel_sz = 3
iterations = 2
structuringElement = cv2.getStructuringElement(cv2.MORPH_RECT, (kernel_sz, kernel_sz))
dilated = cv2.dilate(edges, structuringElement, iterations=iterations)
plt.imshow(dilated, cmap='gray')

# %%
import numpy as np

img_tensor = np.array(img)

# %%
img_tensor.shape
# Out:
# (600, 400, 3)

# %%
img_tensor = image.img_to_array(img)
img_tensor
# Out:
# array([[[255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.],
#         ...,
#         [255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.]],
#
#        [[255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.],
#         ...,
#         [255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.]],
#
#        [[255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.],
#         ...,
#         [255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.]],
#
#        ...,
#
#        [[255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.],
#         ...,
#         [255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.]],
#
#        [[255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.],
#         ...,
#         [255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.]],
#
#        [[255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.],
#         ...,
#         [255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.]]], dtype=float32)

# %%
ref_img = img_tensor
def is_cat(cat_img):
  return np.all((cat_img == ref_img))

# %%
is_cat(img_tensor)
# Out:
# True

# %%
# !wget https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRWXm9UTkw7HBGZePowaSnUGAHdFjHPvEs723ZuKW2ZD1dFHWAw&s
# Out:
# /bin/bash: s: command not found
# --2021-03-26 08:03:08--  https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRWXm9UTkw7HBGZePowaSnUGAHdFjHPvEs723ZuKW2ZD1dFHWAw
# Resolving encrypted-tbn0.gstatic.com (encrypted-tbn0.gstatic.com)... 64.233.166.100, 64.233.166.138, 64.233.166.113, ...
# Connecting to encrypted-tbn0.gstatic.com (encrypted-tbn0.gstatic.com)|64.233.166.100|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6844 (6.7K) [image/jpeg]
# Saving to: ‘images?q=tbn:ANd9GcRWXm9UTkw7HBGZePowaSnUGAHdFjHPvEs723ZuKW2ZD1dFHWAw’
#
# images?q=tbn:ANd9Gc 100%[===================>]   6.68K  --.-KB/s    in 0s
#
# 2021-03-26 08:03:08 (47.0 MB/s) - ‘images?q=tbn:ANd9GcRWXm9UTkw7HBGZePowaSnUGAHdFjHPvEs723ZuKW2ZD1dFHWAw’ saved [6844/6844]

# %%
img = Image.open('images?q=tbn:ANd9GcRWXm9UTkw7HBGZePowaSnUGAHdFjHPvEs723ZuKW2ZD1dFHWAw')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168 at 0x7F9032416B10>

# %%
img.size
# Out:
# (300, 168)

# %%
cat_img = cv2.resize(np.array(img), (400, 600))
cat_img.shape
# Out:
# (600, 400, 3)

# %%
is_cat(cat_img)
# Out:
# False

# %% [markdown]
# # Features
# What we did above is that we used the raw pixels as the only characteristic of the cat. In other words __features__.
#
# We saw features in the survey examples. Those were the questions ready available for __structured data__. But even then, we had to think of the transforms, how to combine quesitons, what to do with duplicate questions,...etc.
#
# In addition, we had to think of the questions weights.
#
# In the cat example of __unstructured data__, the problem of features choice become more clear. Also, we still have the question of weights choice. In the above example, we treated all pixles equally, __but are they?__

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# WE will later discover that the above pattern is called `neuron` or `Dense` or `Fully Connected Layer`.

# %% [markdown]
# # General pattern
#
# We have two main steps we always perform in the 2 examples:
#
# 1. Get the features (questions, pixles), weighted with whatever weights
# 2. Decide on the score, which class?

# %%
class Cat:
  def __init__(self, ref_cat_img):
    self.ref_cat_features = self.get_features(ref_cat_img)
    
  def is_cat(self, cat_img):
    features = self.get_features(cat_img)
    return self.compare_features(features, self.ref_cat_features)
    
  def get_features(self, cat_img):
    
    features = []# eyes, ears,....
    return features
    
  def compare_features(self, cat_img_features, ref_img_features):
    for feature1, feature2 in enumerate(zip(cat_img_features, ref_img_features)):
      if feature1 != feature2:
        return False
    return True

# %%
cat = Cat(ref_img)
cat.is_cat(cat_img)
# Out:
# True

# %%
# !wget https://i.pinimg.com/236x/6b/75/2c/6b752c1cf649066ded40c84eb1915950--ginger-kitten-ginger-cats.jpg
# Out:
# --2021-03-26 08:03:08--  https://i.pinimg.com/236x/6b/75/2c/6b752c1cf649066ded40c84eb1915950--ginger-kitten-ginger-cats.jpg
# Resolving i.pinimg.com (i.pinimg.com)... 104.18.15.176, 104.18.14.176, 2a02:26f0:ce:2b3::1931, ...
# Connecting to i.pinimg.com (i.pinimg.com)|104.18.15.176|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15313 (15K) [image/jpeg]
# Saving to: ‘6b752c1cf649066ded40c84eb1915950--ginger-kitten-ginger-cats.jpg’
#
# 6b752c1cf649066ded4 100%[===================>]  14.95K  --.-KB/s    in 0s
#
# 2021-03-26 08:03:08 (33.3 MB/s) - ‘6b752c1cf649066ded40c84eb1915950--ginger-kitten-ginger-cats.jpg’ saved [15313/15313]

# %%
img2 = image.load_img('6b752c1cf649066ded40c84eb1915950--ginger-kitten-ginger-cats.jpg')
plt.imshow(img2)

# %% [markdown]
# __Pixels are bad features__
#
# In all cases, pixels are not enough. We need morphology (translation, rotation, colr, light/illumination,...etc) invariant features!

# %% [markdown]
# # KNN
#
# Instead of one `ref_cat_img`, can we use many?
#
# If we have lots of cat imgs, we have more and more examples. We could compare to all to them, and say pick the top K relevant cat images. Those are likely to be of the same cat type.
#
# 1- But how to decide on _relevance_? How to decide two cat images are _simiar_? __We need simialrity metric__
#
#
# 2- On what basis we compare cat imgs? What values of the cat image we use for similarity?

# %% [markdown]
# # Can we use better features?
# Say edges?

# %%
img_bgr = cv2.imread('cat.jpg')
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %% [markdown]
# Edges are clearer in gray scale

# %%
gray = cv2.cvtColor(img_rgb, cv2.COLOR_BGR2GRAY)
#gray = cv2.GaussianBlur(gray, (21, 21), 0)
plt.imshow(gray)

# %%
gray.shape
# Out:
# (600, 400)

# %% [markdown]
# We need to use the proper color map

# %%
plt.imshow(gray, cmap='gray')

# %% [markdown]
# Now, edges are more clear in BW images
#
# How to get BW?
#
# Put threshold.
#
# That threshold can same everywhere
#
# Or it can adapt based on the intensity of the region

# %%
thresh = cv2.adaptiveThreshold(gray, 
                               255.0, 
                               cv2.ADAPTIVE_THRESH_GAUSSIAN_C, 
                               cv2.THRESH_BINARY_INV, 19, 20)
plt.imshow(thresh, cmap='gray')

# %% [markdown]
# We can move over this image, and look for the places with change in intensity (0,1,0). OR in 2D: [[0,1,0],[0,1,0],[0,1,0]].
#
# The is called _filtering_
#
# The best edge filter is Canny:

# %%
edges = cv2.Canny(thresh,100,200)
plt.imshow(thresh, cmap='gray')

# %% [markdown]
# Now, let's group points withing regions, by _dilating_ or emphasising them

# %%
kernel_sz = 3
iterations = 2
structuringElement = cv2.getStructuringElement(cv2.MORPH_RECT, (kernel_sz, kernel_sz))
dilated = cv2.dilate(edges, structuringElement, iterations=iterations)
plt.imshow(dilated, cmap='gray')

# %%
contours,hirearchy = cv2.findContours(dilated, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cv2.drawContours(img_rgb, contours, -1, (0, 255, 0), 3) 
plt.imshow(img_rgb)

# %% [markdown]
# We can find structures or around groups of pixels or clusters. These are called contours:

# %%
contours, hierarchy = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

# %%
contours
# Out:
# [array([[[238, 596]],
#
#         [[237, 597]],
#
#         [[238, 598]],
#
#         [[239, 598]],
#
#         [[238, 598]],
#
#         [[237, 597]],
#
#         [[238, 596]],
#
#         [[239, 596]]], dtype=int32), array([[[217, 596]],
#
#         [[217, 597]],
#
#         [[216, 598]],
#
#         [[215, 598]],
#
#         [[214, 598]],
#
#         [[213, 598]],
#
#         [[212, 598]],
#
#         [[211, 598]],
#
#         [[210, 598]],
#
#         [[209, 598]],
#
#         [[208, 598]],
#
#         [[207, 598]],
#
#         [[206, 598]],
#
#         [[207, 598]],
#
#         [[208, 598]],
#
#         [[209, 598]],
#
#         [[210, 598]],
#
#         [[211, 598]],
#
#         [[212, 598]],
#
#         [[213, 598]],
#
#         [[214, 598]],
#
#         [[215, 598]],
#
#         [[216, 598]],
#
#         [[217, 598]],
#
#         [[217, 597]]], dtype=int32), array([[[194, 596]],
#
#         [[195, 596]],
#
#         [[196, 597]],
#
#         [[197, 597]],
#
#         [[198, 597]],
#
#         [[199, 597]],
#
#         [[200, 597]],
#
#         [[201, 597]],
#
#         [[200, 597]],
#
#         [[199, 597]],
#
#         [[198, 597]],
#
#         [[197, 597]],
#
#         [[196, 597]],
#
#         [[195, 596]]], dtype=int32), array([[[191, 596]],
#
#         [[192, 596]]], dtype=int32), array([[[230, 594]],
#
#         [[230, 595]],
#
#         [[229, 596]],
#
#         [[228, 597]],
#
#         [[228, 598]],
#
#         [[228, 597]],
#
#         [[229, 596]],
#
#         [[230, 595]],
#
#         [[231, 594]],
#
#         [[232, 594]],
#
#         [[233, 595]],
#
#         [[233, 596]],
#
#         [[232, 597]],
#
#         [[231, 598]],
#
#         [[232, 597]],
#
#         [[233, 597]],
#
#         [[233, 596]],
#
#         [[233, 595]],
#
#         [[232, 594]],
#
#         [[231, 594]]], dtype=int32), array([[[194, 593]],
#
#         [[193, 594]],
#
#         [[192, 594]],
#
#         [[191, 594]],
#
#         [[192, 594]],
#
#         [[193, 594]],
#
#         [[194, 593]],
#
#         [[195, 593]]], dtype=int32), array([[[199, 590]],
#
#         [[198, 591]],
#
#         [[198, 592]],
#
#         [[198, 593]],
#
#         [[199, 594]],
#
#         [[200, 594]],
#
#         [[201, 595]],
#
#         [[202, 595]],
#
#         [[203, 595]],
#
#         [[204, 595]],
#
#         [[205, 596]],
#
#         [[206, 596]],
#
#         [[207, 596]],
#
#         [[208, 596]],
#
#         [[209, 595]],
#
#         [[210, 595]],
#
#         [[211, 595]],
#
#         [[212, 595]],
#
#         [[213, 595]],
#
#         [[214, 594]],
#
#         [[215, 594]],
#
#         [[216, 594]],
#
#         [[217, 594]],
#
#         [[216, 594]],
#
#         [[215, 594]],
#
#         [[214, 594]],
#
#         [[213, 595]],
#
#         [[212, 595]],
#
#         [[211, 595]],
#
#         [[210, 595]],
#
#         [[209, 595]],
#
#         [[208, 596]],
#
#         [[207, 596]],
#
#         [[206, 596]],
#
#         [[205, 596]],
#
#         [[204, 595]],
#
#         [[203, 595]],
#
#         [[202, 595]],
#
#         [[201, 595]],
#
#         [[200, 594]],
#
#         [[199, 594]],
#
#         [[198, 593]],
#
#         [[198, 592]],
#
#         [[199, 591]]], dtype=int32), array([[[189, 588]],
#
#         [[188, 589]],
#
#         [[188, 590]],
#
#         [[188, 591]],
#
#         [[188, 592]],
#
#         [[188, 593]],
#
#         [[187, 594]],
#
#         [[186, 594]],
#
#         [[185, 594]],
#
#         [[184, 594]],
#
#         [[185, 594]],
#
#         [[186, 594]],
#
#         [[187, 594]],
#
#         [[188, 593]],
#
#         [[189, 593]],
#
#         [[188, 592]],
#
#         [[188, 591]],
#
#         [[188, 590]],
#
#         [[188, 589]]], dtype=int32), array([[[180, 588]],
#
#         [[179, 589]],
#
#         [[179, 590]],
#
#         [[179, 589]],
#
#         [[180, 588]],
#
#         [[181, 589]],
#
#         [[181, 590]],
#
#         [[181, 589]]], dtype=int32), array([[[199, 585]],
#
#         [[198, 586]],
#
#         [[198, 587]],
#
#         [[198, 588]],
#
#         [[197, 589]],
#
#         [[196, 590]],
#
#         [[196, 591]],
#
#         [[196, 590]],
#
#         [[197, 589]],
#
#         [[198, 588]],
#
#         [[198, 587]],
#
#         [[198, 586]],
#
#         [[199, 585]],
#
#         [[200, 586]],
#
#         [[200, 587]],
#
#         [[200, 588]],
#
#         [[200, 587]],
#
#         [[200, 586]]], dtype=int32), array([[[188, 585]],
#
#         [[187, 586]],
#
#         [[186, 587]],
#
#         [[185, 588]],
#
#         [[184, 589]],
#
#         [[183, 590]],
#
#         [[183, 591]],
#
#         [[182, 592]],
#
#         [[182, 593]],
#
#         [[182, 592]],
#
#         [[183, 591]],
#
#         [[184, 590]],
#
#         [[185, 589]],
#
#         [[186, 588]],
#
#         [[187, 587]],
#
#         [[187, 586]],
#
#         [[188, 585]],
#
#         [[189, 585]]], dtype=int32), array([[[195, 582]],
#
#         [[194, 583]]], dtype=int32), array([[[192, 582]],
#
#         [[192, 583]]], dtype=int32), array([[[264, 580]],
#
#         [[265, 580]]], dtype=int32), array([[[195, 580]]], dtype=int32), array([[[193, 580]]], dtype=int32), array([[[264, 578]],
#
#         [[265, 578]]], dtype=int32), array([[[258, 576]],
#
#         [[258, 577]],
#
#         [[258, 578]],
#
#         [[259, 579]],
#
#         [[260, 579]],
#
#         [[261, 579]],
#
#         [[261, 578]],
#
#         [[261, 577]],
#
#         [[261, 576]],
#
#         [[260, 576]],
#
#         [[259, 576]]], dtype=int32), array([[[132, 576]],
#
#         [[133, 576]],
#
#         [[134, 577]],
#
#         [[135, 577]],
#
#         [[136, 577]],
#
#         [[137, 577]],
#
#         [[138, 577]],
#
#         [[139, 577]],
#
#         [[140, 577]],
#
#         [[141, 577]],
#
#         [[142, 577]],
#
#         [[143, 577]],
#
#         [[144, 577]],
#
#         [[145, 577]],
#
#         [[146, 577]],
#
#         [[147, 577]],
#
#         [[148, 577]],
#
#         [[149, 577]],
#
#         [[150, 577]],
#
#         [[151, 577]],
#
#         [[152, 577]],
#
#         [[153, 577]],
#
#         [[154, 577]],
#
#         [[155, 577]],
#
#         [[156, 577]],
#
#         [[157, 577]],
#
#         [[158, 577]],
#
#         [[159, 577]],
#
#         [[160, 577]],
#
#         [[161, 577]],
#
#         [[162, 577]],
#
#         [[163, 577]],
#
#         [[164, 577]],
#
#         [[163, 577]],
#
#         [[162, 577]],
#
#         [[161, 577]],
#
#         [[160, 577]],
#
#         [[159, 577]],
#
#         [[158, 577]],
#
#         [[157, 577]],
#
#         [[156, 577]],
#
#         [[155, 577]],
#
#         [[154, 577]],
#
#         [[153, 577]],
#
#         [[152, 577]],
#
#         [[151, 577]],
#
#         [[150, 577]],
#
#         [[149, 577]],
#
#         [[148, 577]],
#
#         [[147, 577]],
#
#         [[146, 577]],
#
#         [[145, 577]],
#
#         [[144, 577]],
#
#         [[143, 577]],
#
#         [[142, 577]],
#
#         [[141, 577]],
#
#         [[140, 577]],
#
#         [[139, 577]],
#
#         [[138, 577]],
#
#         [[137, 577]],
#
#         [[136, 577]],
#
#         [[135, 577]],
#
#         [[134, 577]],
#
#         [[133, 576]]], dtype=int32), array([[[126, 572]],
#
#         [[125, 573]],
#
#         [[124, 573]],
#
#         [[124, 574]],
#
#         [[125, 575]],
#
#         [[126, 575]],
#
#         [[127, 575]],
#
#         [[128, 575]],
#
#         [[129, 575]],
#
#         [[128, 575]],
#
#         [[127, 575]],
#
#         [[126, 575]],
#
#         [[125, 575]],
#
#         [[124, 574]],
#
#         [[125, 573]],
#
#         [[126, 572]],
#
#         [[127, 572]],
#
#         [[128, 572]],
#
#         [[129, 573]],
#
#         [[130, 573]],
#
#         [[131, 573]],
#
#         [[132, 574]],
#
#         [[133, 574]],
#
#         [[134, 574]],
#
#         [[135, 574]],
#
#         [[136, 574]],
#
#         [[137, 574]],
#
#         [[138, 574]],
#
#         [[139, 574]],
#
#         [[140, 574]],
#
#         [[141, 574]],
#
#         [[142, 574]],
#
#         [[143, 574]],
#
#         [[144, 573]],
#
#         [[145, 573]],
#
#         [[146, 573]],
#
#         [[147, 574]],
#
#         [[148, 574]],
#
#         [[149, 574]],
#
#         [[150, 574]],
#
#         [[151, 574]],
#
#         [[152, 574]],
#
#         [[153, 574]],
#
#         [[154, 574]],
#
#         [[155, 574]],
#
#         [[156, 574]],
#
#         [[157, 574]],
#
#         [[158, 574]],
#
#         [[159, 574]],
#
#         [[159, 573]],
#
#         [[160, 572]],
#
#         [[161, 573]],
#
#         [[162, 574]],
#
#         [[163, 574]],
#
#         [[164, 574]],
#
#         [[165, 574]],
#
#         [[166, 574]],
#
#         [[167, 574]],
#
#         [[168, 573]],
#
#         [[169, 574]],
#
#         [[169, 575]],
#
#         [[168, 576]],
#
#         [[167, 576]],
#
#         [[168, 576]],
#
#         [[169, 575]],
#
#         [[169, 574]],
#
#         [[169, 573]],
#
#         [[168, 573]],
#
#         [[167, 573]],
#
#         [[166, 574]],
#
#         [[165, 574]],
#
#         [[164, 574]],
#
#         [[163, 574]],
#
#         [[162, 573]],
#
#         [[161, 572]],
#
#         [[160, 572]],
#
#         [[159, 572]],
#
#         [[159, 573]],
#
#         [[158, 574]],
#
#         [[157, 574]],
#
#         [[156, 574]],
#
#         [[155, 574]],
#
#         [[154, 574]],
#
#         [[153, 574]],
#
#         [[152, 574]],
#
#         [[151, 574]],
#
#         [[150, 574]],
#
#         [[149, 574]],
#
#         [[148, 574]],
#
#         [[147, 574]],
#
#         [[146, 573]],
#
#         [[145, 573]],
#
#         [[144, 573]],
#
#         [[143, 574]],
#
#         [[142, 574]],
#
#         [[141, 574]],
#
#         [[140, 574]],
#
#         [[139, 574]],
#
#         [[138, 574]],
#
#         [[137, 574]],
#
#         [[136, 574]],
#
#         [[135, 574]],
#
#         [[134, 574]],
#
#         [[133, 574]],
#
#         [[132, 574]],
#
#         [[131, 573]],
#
#         [[130, 573]],
#
#         [[129, 573]],
#
#         [[128, 572]],
#
#         [[127, 572]]], dtype=int32), array([[[302, 570]],
#
#         [[301, 571]],
#
#         [[300, 572]],
#
#         [[300, 573]],
#
#         [[301, 572]],
#
#         [[302, 573]],
#
#         [[303, 573]],
#
#         [[304, 573]],
#
#         [[304, 572]],
#
#         [[304, 571]],
#
#         [[304, 570]],
#
#         [[303, 570]]], dtype=int32), array([[[296, 569]],
#
#         [[295, 570]],
#
#         [[294, 570]],
#
#         [[294, 571]],
#
#         [[293, 572]],
#
#         [[292, 573]],
#
#         [[291, 573]],
#
#         [[290, 573]],
#
#         [[289, 573]],
#
#         [[288, 573]],
#
#         [[287, 573]],
#
#         [[286, 573]],
#
#         [[285, 573]],
#
#         [[284, 574]],
#
#         [[283, 574]],
#
#         [[282, 574]],
#
#         [[281, 574]],
#
#         [[280, 574]],
#
#         [[279, 574]],
#
#         [[278, 574]],
#
#         [[277, 574]],
#
#         [[276, 574]],
#
#         [[275, 574]],
#
#         [[274, 575]],
#
#         [[273, 575]],
#
#         [[272, 575]],
#
#         [[271, 575]],
#
#         [[270, 575]],
#
#         [[269, 576]],
#
#         [[268, 576]],
#
#         [[268, 577]],
#
#         [[268, 578]],
#
#         [[269, 578]],
#
#         [[270, 579]],
#
#         [[271, 579]],
#
#         [[272, 579]],
#
#         [[273, 579]],
#
#         [[274, 579]],
#
#         [[275, 579]],
#
#         [[276, 579]],
#
#         [[277, 578]],
#
#         [[278, 578]],
#
#         [[279, 578]],
#
#         [[280, 578]],
#
#         [[281, 578]],
#
#         [[282, 578]],
#
#         [[283, 578]],
#
#         [[284, 578]],
#
#         [[285, 578]],
#
#         [[286, 577]],
#
#         [[287, 577]],
#
#         [[288, 577]],
#
#         [[289, 577]],
#
#         [[290, 577]],
#
#         [[291, 576]],
#
#         [[290, 576]],
#
#         [[289, 577]],
#
#         [[288, 577]],
#
#         [[287, 577]],
#
#         [[286, 577]],
#
#         [[285, 578]],
#
#         [[284, 578]],
#
#         [[283, 578]],
#
#         [[282, 578]],
#
#         [[281, 578]],
#
#         [[280, 578]],
#
#         [[279, 578]],
#
#         [[278, 578]],
#
#         [[277, 578]],
#
#         [[276, 579]],
#
#         [[275, 579]],
#
#         [[274, 579]],
#
#         [[273, 579]],
#
#         [[272, 579]],
#
#         [[271, 579]],
#
#         [[270, 579]],
#
#         [[269, 578]],
#
#         [[268, 577]],
#
#         [[269, 576]],
#
#         [[270, 575]],
#
#         [[271, 575]],
#
#         [[272, 575]],
#
#         [[273, 575]],
#
#         [[274, 575]],
#
#         [[275, 574]],
#
#         [[276, 574]],
#
#         [[277, 574]],
#
#         [[278, 574]],
#
#         [[279, 574]],
#
#         [[280, 574]],
#
#         [[281, 574]],
#
#         [[282, 574]],
#
#         [[283, 574]],
#
#         [[284, 574]],
#
#         [[285, 573]],
#
#         [[286, 573]],
#
#         [[287, 573]],
#
#         [[288, 573]],
#
#         [[289, 573]],
#
#         [[290, 573]],
#
#         [[291, 573]],
#
#         [[292, 573]],
#
#         [[293, 573]],
#
#         [[293, 572]],
#
#         [[294, 571]],
#
#         [[295, 570]],
#
#         [[296, 569]],
#
#         [[297, 569]],
#
#         [[298, 570]],
#
#         [[298, 571]],
#
#         [[298, 572]],
#
#         [[298, 573]],
#
#         [[297, 574]],
#
#         [[296, 574]],
#
#         [[295, 575]],
#
#         [[294, 575]],
#
#         [[293, 575]],
#
#         [[294, 575]],
#
#         [[295, 575]],
#
#         [[296, 574]],
#
#         [[297, 574]],
#
#         [[298, 574]],
#
#         [[298, 573]],
#
#         [[298, 572]],
#
#         [[298, 571]],
#
#         [[298, 570]],
#
#         [[297, 569]]], dtype=int32), array([[[110, 568]],
#
#         [[109, 569]],
#
#         [[110, 570]],
#
#         [[111, 570]],
#
#         [[112, 570]],
#
#         [[113, 570]],
#
#         [[113, 569]],
#
#         [[113, 568]],
#
#         [[112, 568]],
#
#         [[111, 568]]], dtype=int32), array([[[302, 565]],
#
#         [[301, 566]],
#
#         [[300, 567]],
#
#         [[301, 568]],
#
#         [[302, 568]],
#
#         [[303, 568]],
#
#         [[304, 568]],
#
#         [[305, 567]],
#
#         [[305, 566]],
#
#         [[305, 565]],
#
#         [[304, 565]],
#
#         [[303, 565]]], dtype=int32), array([[[307, 562]],
#
#         [[307, 563]],
#
#         [[308, 564]],
#
#         [[309, 563]],
#
#         [[309, 562]],
#
#         [[308, 562]]], dtype=int32), array([[[318, 560]],
#
#         [[317, 561]],
#
#         [[316, 561]],
#
#         [[315, 562]],
#
#         [[314, 563]],
#
#         [[314, 564]],
#
#         [[314, 565]],
#
#         [[313, 566]],
#
#         [[312, 567]],
#
#         [[311, 568]],
#
#         [[312, 569]],
#
#         [[313, 569]],
#
#         [[312, 569]],
#
#         [[311, 568]],
#
#         [[312, 567]],
#
#         [[313, 567]],
#
#         [[314, 567]],
#
#         [[315, 568]],
#
#         [[314, 567]],
#
#         [[313, 566]],
#
#         [[314, 565]],
#
#         [[315, 565]],
#
#         [[316, 565]],
#
#         [[317, 565]],
#
#         [[317, 564]],
#
#         [[318, 563]],
#
#         [[319, 562]],
#
#         [[319, 561]]], dtype=int32), array([[[140, 559]],
#
#         [[140, 560]],
#
#         [[140, 561]],
#
#         [[141, 561]],
#
#         [[142, 561]],
#
#         [[142, 560]],
#
#         [[142, 559]],
#
#         [[141, 559]]], dtype=int32), array([[[291, 558]],
#
#         [[291, 559]],
#
#         [[291, 560]],
#
#         [[292, 560]],
#
#         [[293, 560]],
#
#         [[293, 559]],
#
#         [[293, 558]],
#
#         [[292, 558]]], dtype=int32), array([[[308, 555]],
#
#         [[309, 555]]], dtype=int32), array([[[329, 554]],
#
#         [[328, 555]],
#
#         [[327, 556]],
#
#         [[326, 557]],
#
#         [[325, 558]],
#
#         [[325, 559]],
#
#         [[325, 560]],
#
#         [[325, 561]],
#
#         [[326, 561]],
#
#         [[327, 561]],
#
#         [[328, 560]],
#
#         [[329, 559]],
#
#         [[330, 559]],
#
#         [[330, 558]],
#
#         [[330, 557]],
#
#         [[330, 556]],
#
#         [[329, 555]],
#
#         [[330, 554]]], dtype=int32), array([[[307, 553]],
#
#         [[306, 554]],
#
#         [[306, 555]],
#
#         [[306, 554]],
#
#         [[307, 553]],
#
#         [[308, 553]],
#
#         [[309, 553]],
#
#         [[308, 553]]], dtype=int32), array([[[333, 552]],
#
#         [[333, 553]],
#
#         [[333, 554]],
#
#         [[334, 554]],
#
#         [[335, 554]],
#
#         [[335, 553]],
#
#         [[335, 552]],
#
#         [[334, 552]]], dtype=int32), array([[[259, 551]],
#
#         [[259, 552]],
#
#         [[258, 553]],
#
#         [[258, 554]],
#
#         [[257, 555]],
#
#         [[257, 556]],
#
#         [[256, 557]],
#
#         [[255, 558]],
#
#         [[255, 559]],
#
#         [[254, 560]],
#
#         [[253, 560]],
#
#         [[252, 559]],
#
#         [[252, 560]],
#
#         [[253, 560]],
#
#         [[254, 560]],
#
#         [[255, 559]],
#
#         [[256, 558]],
#
#         [[257, 557]],
#
#         [[257, 556]],
#
#         [[257, 555]],
#
#         [[258, 554]],
#
#         [[259, 553]],
#
#         [[259, 552]]], dtype=int32), array([[[334, 549]]], dtype=int32), array([[[258, 549]],
#
#         [[257, 550]],
#
#         [[256, 551]],
#
#         [[255, 551]],
#
#         [[255, 552]],
#
#         [[254, 553]],
#
#         [[253, 554]],
#
#         [[253, 555]],
#
#         [[253, 556]],
#
#         [[253, 557]],
#
#         [[253, 556]],
#
#         [[253, 555]],
#
#         [[254, 554]],
#
#         [[254, 553]],
#
#         [[255, 552]],
#
#         [[256, 551]],
#
#         [[257, 550]],
#
#         [[258, 549]],
#
#         [[259, 549]]], dtype=int32), array([[[321, 548]],
#
#         [[322, 548]],
#
#         [[323, 549]],
#
#         [[322, 550]],
#
#         [[321, 550]],
#
#         [[320, 551]],
#
#         [[319, 551]],
#
#         [[318, 550]],
#
#         [[319, 549]],
#
#         [[318, 549]],
#
#         [[318, 550]],
#
#         [[318, 551]],
#
#         [[319, 551]],
#
#         [[320, 551]],
#
#         [[321, 550]],
#
#         [[322, 550]],
#
#         [[323, 550]],
#
#         [[323, 549]],
#
#         [[323, 548]],
#
#         [[322, 548]]], dtype=int32), array([[[335, 547]],
#
#         [[336, 548]],
#
#         [[336, 549]],
#
#         [[336, 548]]], dtype=int32), array([[[341, 546]],
#
#         [[340, 547]],
#
#         [[340, 548]],
#
#         [[340, 547]],
#
#         [[341, 546]],
#
#         [[342, 547]],
#
#         [[342, 548]],
#
#         [[342, 547]]], dtype=int32), array([[[331, 544]],
#
#         [[330, 545]],
#
#         [[330, 546]],
#
#         [[329, 547]],
#
#         [[330, 548]],
#
#         [[331, 548]],
#
#         [[332, 548]],
#
#         [[333, 547]],
#
#         [[333, 546]],
#
#         [[333, 545]],
#
#         [[333, 544]],
#
#         [[332, 544]]], dtype=int32), array([[[350, 541]],
#
#         [[349, 542]],
#
#         [[350, 543]],
#
#         [[351, 543]],
#
#         [[352, 543]],
#
#         [[352, 542]],
#
#         [[352, 541]],
#
#         [[351, 541]]], dtype=int32), array([[[215, 541]]], dtype=int32), array([[[346, 540]]], dtype=int32), array([[[214, 539]],
#
#         [[213, 540]],
#
#         [[213, 541]],
#
#         [[213, 540]],
#
#         [[214, 539]],
#
#         [[215, 539]]], dtype=int32), array([[[345, 538]],
#
#         [[344, 539]],
#
#         [[343, 540]],
#
#         [[343, 541]],
#
#         [[344, 542]],
#
#         [[343, 541]],
#
#         [[343, 540]],
#
#         [[344, 539]],
#
#         [[345, 538]],
#
#         [[346, 538]],
#
#         [[347, 538]],
#
#         [[346, 538]]], dtype=int32), array([[[283, 538]],
#
#         [[282, 539]],
#
#         [[283, 540]],
#
#         [[284, 540]],
#
#         [[285, 540]],
#
#         [[286, 540]],
#
#         [[286, 539]],
#
#         [[286, 538]],
#
#         [[285, 538]],
#
#         [[284, 538]]], dtype=int32), array([[[330, 534]],
#
#         [[329, 535]],
#
#         [[329, 536]],
#
#         [[329, 535]],
#
#         [[330, 534]],
#
#         [[331, 535]],
#
#         [[331, 536]],
#
#         [[331, 535]]], dtype=int32), array([[[362, 526]],
#
#         [[362, 527]],
#
#         [[362, 528]],
#
#         [[363, 528]],
#
#         [[364, 528]],
#
#         [[364, 527]],
#
#         [[364, 526]],
#
#         [[363, 526]]], dtype=int32), array([[[137, 525]],
#
#         [[136, 526]],
#
#         [[135, 526]],
#
#         [[134, 527]],
#
#         [[133, 528]],
#
#         [[133, 529]],
#
#         [[134, 528]],
#
#         [[135, 529]],
#
#         [[136, 529]],
#
#         [[137, 529]],
#
#         [[138, 528]],
#
#         [[139, 528]],
#
#         [[139, 527]],
#
#         [[138, 528]],
#
#         [[137, 529]],
#
#         [[136, 529]],
#
#         [[135, 529]],
#
#         [[134, 528]],
#
#         [[135, 527]],
#
#         [[136, 526]],
#
#         [[137, 525]],
#
#         [[138, 525]],
#
#         [[139, 525]],
#
#         [[138, 525]]], dtype=int32), array([[[252, 524]],
#
#         [[252, 525]],
#
#         [[253, 526]],
#
#         [[254, 526]],
#
#         [[255, 526]],
#
#         [[254, 526]],
#
#         [[253, 526]],
#
#         [[252, 525]],
#
#         [[253, 524]],
#
#         [[254, 524]],
#
#         [[255, 524]],
#
#         [[256, 524]],
#
#         [[255, 524]],
#
#         [[254, 524]],
#
#         [[253, 524]]], dtype=int32), array([[[311, 516]],
#
#         [[311, 517]],
#
#         [[312, 518]],
#
#         [[313, 517]],
#
#         [[313, 516]],
#
#         [[312, 516]]], dtype=int32), array([[[260, 516]],
#
#         [[260, 517]]], dtype=int32), array([[[258, 516]],
#
#         [[258, 517]]], dtype=int32), array([[[287, 513]],
#
#         [[288, 514]],
#
#         [[288, 515]],
#
#         [[288, 516]],
#
#         [[288, 517]],
#
#         [[288, 518]],
#
#         [[288, 519]],
#
#         [[288, 520]],
#
#         [[288, 521]],
#
#         [[288, 522]],
#
#         [[288, 521]],
#
#         [[288, 520]],
#
#         [[288, 519]],
#
#         [[288, 518]],
#
#         [[288, 517]],
#
#         [[288, 516]],
#
#         [[288, 515]],
#
#         [[288, 514]]], dtype=int32), array([[[259, 512]],
#
#         [[258, 513]],
#
#         [[258, 514]],
#
#         [[259, 514]],
#
#         [[260, 514]],
#
#         [[260, 513]],
#
#         [[260, 512]]], dtype=int32), array([[[289, 511]],
#
#         [[290, 512]],
#
#         [[290, 513]],
#
#         [[291, 514]],
#
#         [[291, 515]],
#
#         [[292, 515]],
#
#         [[293, 515]],
#
#         [[294, 515]],
#
#         [[295, 516]],
#
#         [[295, 517]],
#
#         [[294, 518]],
#
#         [[293, 519]],
#
#         [[292, 520]],
#
#         [[291, 520]],
#
#         [[290, 521]],
#
#         [[291, 520]],
#
#         [[292, 520]],
#
#         [[293, 519]],
#
#         [[294, 519]],
#
#         [[295, 518]],
#
#         [[295, 517]],
#
#         [[295, 516]],
#
#         [[294, 515]],
#
#         [[293, 515]],
#
#         [[292, 515]],
#
#         [[291, 514]],
#
#         [[290, 513]],
#
#         [[290, 512]]], dtype=int32), array([[[287, 511]]], dtype=int32), array([[[255, 511]],
#
#         [[255, 512]],
#
#         [[256, 512]],
#
#         [[257, 511]],
#
#         [[256, 512]]], dtype=int32), array([[[176, 509]],
#
#         [[176, 510]],
#
#         [[176, 511]],
#
#         [[176, 512]],
#
#         [[176, 513]],
#
#         [[177, 513]],
#
#         [[178, 513]],
#
#         [[178, 512]],
#
#         [[177, 513]],
#
#         [[176, 512]],
#
#         [[176, 511]],
#
#         [[176, 510]],
#
#         [[177, 509]],
#
#         [[178, 509]],
#
#         [[177, 509]]], dtype=int32), array([[[309, 508]],
#
#         [[308, 509]],
#
#         [[307, 509]],
#
#         [[306, 509]],
#
#         [[305, 509]],
#
#         [[304, 509]],
#
#         [[305, 509]],
#
#         [[306, 509]],
#
#         [[307, 509]],
#
#         [[308, 509]]], dtype=int32), array([[[310, 506]]], dtype=int32), array([[[255, 506]],
#
#         [[255, 507]],
#
#         [[255, 508]],
#
#         [[255, 507]],
#
#         [[256, 506]],
#
#         [[257, 507]],
#
#         [[256, 506]]], dtype=int32), array([[[308, 505]],
#
#         [[307, 506]],
#
#         [[306, 507]],
#
#         [[305, 506]],
#
#         [[304, 506]],
#
#         [[303, 506]],
#
#         [[302, 507]],
#
#         [[301, 508]],
#
#         [[301, 509]],
#
#         [[301, 508]],
#
#         [[302, 507]],
#
#         [[303, 507]],
#
#         [[304, 506]],
#
#         [[305, 507]],
#
#         [[306, 507]],
#
#         [[307, 506]]], dtype=int32), array([[[226, 505]],
#
#         [[227, 505]]], dtype=int32), array([[[271, 504]],
#
#         [[271, 505]],
#
#         [[270, 506]],
#
#         [[270, 507]],
#
#         [[270, 508]],
#
#         [[271, 508]],
#
#         [[272, 508]],
#
#         [[273, 508]],
#
#         [[273, 507]],
#
#         [[273, 506]],
#
#         [[273, 505]],
#
#         [[273, 504]],
#
#         [[272, 504]]], dtype=int32), array([[[315, 503]]], dtype=int32), array([[[309, 503]],
#
#         [[310, 503]]], dtype=int32), array([[[234, 503]],
#
#         [[234, 504]],
#
#         [[234, 505]],
#
#         [[235, 505]],
#
#         [[236, 505]],
#
#         [[236, 504]],
#
#         [[236, 503]],
#
#         [[235, 503]]], dtype=int32), array([[[177, 503]],
#
#         [[176, 504]],
#
#         [[177, 505]],
#
#         [[178, 505]],
#
#         [[177, 505]],
#
#         [[176, 504]],
#
#         [[177, 503]],
#
#         [[178, 503]]], dtype=int32), array([[[225, 502]],
#
#         [[224, 503]],
#
#         [[225, 502]],
#
#         [[226, 503]],
#
#         [[227, 503]],
#
#         [[226, 503]]], dtype=int32), array([[[315, 501]]], dtype=int32), array([[[321, 500]],
#
#         [[320, 501]],
#
#         [[321, 502]],
#
#         [[321, 503]],
#
#         [[322, 503]],
#
#         [[323, 503]],
#
#         [[323, 502]],
#
#         [[323, 501]],
#
#         [[323, 500]],
#
#         [[322, 500]]], dtype=int32), array([[[313, 499]],
#
#         [[313, 500]],
#
#         [[313, 501]],
#
#         [[313, 502]],
#
#         [[313, 501]],
#
#         [[313, 500]],
#
#         [[314, 499]]], dtype=int32), array([[[176, 498]],
#
#         [[175, 499]],
#
#         [[176, 500]],
#
#         [[177, 500]],
#
#         [[176, 500]],
#
#         [[175, 499]],
#
#         [[176, 498]],
#
#         [[177, 498]]], dtype=int32), array([[[176, 492]],
#
#         [[175, 493]],
#
#         [[176, 494]],
#
#         [[177, 494]],
#
#         [[176, 494]],
#
#         [[175, 493]],
#
#         [[176, 492]],
#
#         [[177, 492]]], dtype=int32), array([[[295, 491]],
#
#         [[294, 492]],
#
#         [[294, 493]],
#
#         [[294, 494]],
#
#         [[294, 495]],
#
#         [[295, 495]],
#
#         [[296, 495]],
#
#         [[296, 494]],
#
#         [[296, 493]],
#
#         [[296, 492]]], dtype=int32), array([[[337, 489]],
#
#         [[337, 490]],
#
#         [[337, 491]],
#
#         [[338, 491]],
#
#         [[339, 491]],
#
#         [[339, 490]],
#
#         [[339, 489]],
#
#         [[338, 489]]], dtype=int32), array([[[175, 486]],
#
#         [[175, 487]],
#
#         [[175, 488]],
#
#         [[176, 488]],
#
#         [[177, 488]],
#
#         [[177, 487]],
#
#         [[177, 486]],
#
#         [[176, 486]]], dtype=int32), array([[[167, 455]],
#
#         [[168, 455]]], dtype=int32), array([[[201, 453]],
#
#         [[200, 454]],
#
#         [[201, 455]],
#
#         [[202, 455]],
#
#         [[201, 455]],
#
#         [[200, 454]],
#
#         [[201, 453]],
#
#         [[202, 453]]], dtype=int32), array([[[164, 452]],
#
#         [[164, 453]],
#
#         [[164, 454]],
#
#         [[165, 454]],
#
#         [[164, 453]],
#
#         [[165, 452]],
#
#         [[166, 452]],
#
#         [[167, 453]],
#
#         [[168, 453]],
#
#         [[167, 453]],
#
#         [[166, 452]],
#
#         [[165, 452]]], dtype=int32), array([[[177, 450]],
#
#         [[177, 451]],
#
#         [[177, 452]],
#
#         [[178, 452]],
#
#         [[179, 452]],
#
#         [[179, 451]],
#
#         [[179, 450]],
#
#         [[178, 450]]], dtype=int32), array([[[201, 449]]], dtype=int32), array([[[199, 449]]], dtype=int32), array([[[114, 449]]], dtype=int32), array([[[112, 449]]], dtype=int32), array([[[203, 448]]], dtype=int32), array([[[192, 448]],
#
#         [[192, 449]],
#
#         [[192, 450]],
#
#         [[193, 450]],
#
#         [[194, 450]],
#
#         [[194, 449]],
#
#         [[194, 448]],
#
#         [[193, 448]]], dtype=int32), array([[[113, 447]],
#
#         [[114, 447]]], dtype=int32), array([[[202, 446]],
#
#         [[201, 447]],
#
#         [[202, 446]],
#
#         [[203, 446]]], dtype=int32), array([[[199, 445]]], dtype=int32), array([[[155, 442]],
#
#         [[155, 443]],
#
#         [[156, 442]],
#
#         [[157, 442]],
#
#         [[156, 442]]], dtype=int32), array([[[199, 441]],
#
#         [[199, 442]],
#
#         [[198, 443]],
#
#         [[197, 444]],
#
#         [[197, 445]],
#
#         [[197, 444]],
#
#         [[198, 443]],
#
#         [[199, 442]],
#
#         [[200, 441]],
#
#         [[201, 442]],
#
#         [[201, 443]],
#
#         [[201, 442]],
#
#         [[201, 441]],
#
#         [[200, 441]]], dtype=int32), array([[[101, 439]]], dtype=int32), array([[[ 99, 439]],
#
#         [[ 99, 440]]], dtype=int32), array([[[214, 438]],
#
#         [[213, 439]],
#
#         [[212, 440]],
#
#         [[211, 441]],
#
#         [[211, 442]],
#
#         [[211, 443]],
#
#         [[212, 443]],
#
#         [[213, 443]],
#
#         [[213, 442]],
#
#         [[212, 443]],
#
#         [[211, 442]],
#
#         [[211, 441]],
#
#         [[212, 440]],
#
#         [[213, 439]]], dtype=int32), array([[[255, 435]]], dtype=int32), array([[[155, 435]],
#
#         [[155, 436]],
#
#         [[155, 437]],
#
#         [[155, 436]],
#
#         [[156, 435]]], dtype=int32), array([[[244, 433]],
#
#         [[243, 434]],
#
#         [[243, 435]],
#
#         [[243, 436]],
#
#         [[244, 436]],
#
#         [[245, 436]],
#
#         [[245, 435]],
#
#         [[245, 434]]], dtype=int32), array([[[123, 433]],
#
#         [[123, 434]],
#
#         [[123, 435]],
#
#         [[124, 435]],
#
#         [[125, 435]],
#
#         [[125, 434]],
#
#         [[125, 433]],
#
#         [[124, 433]]], dtype=int32), array([[[248, 432]],
#
#         [[247, 433]],
#
#         [[247, 434]],
#
#         [[247, 433]],
#
#         [[248, 432]],
#
#         [[249, 433]],
#
#         [[249, 434]],
#
#         [[250, 435]],
#
#         [[251, 435]],
#
#         [[252, 435]],
#
#         [[253, 435]],
#
#         [[253, 434]],
#
#         [[254, 433]],
#
#         [[253, 433]],
#
#         [[252, 433]],
#
#         [[251, 433]],
#
#         [[252, 433]],
#
#         [[253, 434]],
#
#         [[252, 435]],
#
#         [[251, 435]],
#
#         [[250, 435]],
#
#         [[249, 434]],
#
#         [[249, 433]]], dtype=int32), array([[[221, 432]],
#
#         [[220, 433]],
#
#         [[220, 434]],
#
#         [[219, 435]],
#
#         [[219, 436]],
#
#         [[219, 437]],
#
#         [[219, 438]],
#
#         [[220, 438]],
#
#         [[221, 438]],
#
#         [[221, 437]],
#
#         [[221, 436]],
#
#         [[220, 435]],
#
#         [[220, 434]],
#
#         [[220, 433]],
#
#         [[221, 432]],
#
#         [[222, 433]],
#
#         [[222, 434]],
#
#         [[222, 433]]], dtype=int32), array([[[146, 431]],
#
#         [[146, 432]],
#
#         [[147, 433]],
#
#         [[148, 432]],
#
#         [[148, 431]],
#
#         [[147, 431]]], dtype=int32), array([[[238, 429]],
#
#         [[237, 430]],
#
#         [[237, 431]],
#
#         [[237, 432]],
#
#         [[237, 433]],
#
#         [[237, 434]],
#
#         [[238, 435]],
#
#         [[237, 434]],
#
#         [[237, 433]],
#
#         [[237, 432]],
#
#         [[237, 431]],
#
#         [[237, 430]],
#
#         [[238, 429]],
#
#         [[239, 430]],
#
#         [[239, 431]],
#
#         [[239, 432]],
#
#         [[239, 433]],
#
#         [[239, 432]],
#
#         [[239, 431]],
#
#         [[239, 430]]], dtype=int32), array([[[145, 428]]], dtype=int32), array([[[114, 428]],
#
#         [[113, 429]],
#
#         [[113, 430]],
#
#         [[113, 429]],
#
#         [[114, 428]],
#
#         [[115, 429]],
#
#         [[115, 430]],
#
#         [[115, 429]]], dtype=int32), array([[[196, 426]],
#
#         [[196, 427]],
#
#         [[197, 426]]], dtype=int32), array([[[255, 425]],
#
#         [[254, 426]],
#
#         [[255, 427]],
#
#         [[256, 427]],
#
#         [[255, 427]],
#
#         [[254, 426]],
#
#         [[255, 425]],
#
#         [[256, 425]]], dtype=int32), array([[[150, 425]],
#
#         [[149, 426]],
#
#         [[149, 427]],
#
#         [[149, 428]],
#
#         [[150, 429]],
#
#         [[150, 430]],
#
#         [[150, 431]],
#
#         [[150, 432]],
#
#         [[151, 433]],
#
#         [[151, 434]],
#
#         [[152, 434]],
#
#         [[153, 434]],
#
#         [[153, 433]],
#
#         [[153, 432]],
#
#         [[153, 431]],
#
#         [[153, 430]],
#
#         [[153, 429]],
#
#         [[152, 429]],
#
#         [[151, 429]],
#
#         [[150, 429]],
#
#         [[149, 428]],
#
#         [[149, 427]],
#
#         [[149, 426]],
#
#         [[150, 425]],
#
#         [[151, 426]],
#
#         [[151, 427]],
#
#         [[151, 426]]], dtype=int32), array([[[144, 425]],
#
#         [[144, 426]],
#
#         [[145, 425]],
#
#         [[146, 425]],
#
#         [[145, 425]]], dtype=int32), array([[[202, 424]],
#
#         [[201, 425]],
#
#         [[200, 425]],
#
#         [[200, 426]],
#
#         [[199, 427]],
#
#         [[199, 428]],
#
#         [[199, 427]],
#
#         [[200, 426]],
#
#         [[201, 425]],
#
#         [[202, 424]],
#
#         [[203, 425]],
#
#         [[203, 426]],
#
#         [[202, 427]],
#
#         [[201, 428]],
#
#         [[202, 427]],
#
#         [[203, 426]],
#
#         [[203, 425]],
#
#         [[204, 424]],
#
#         [[203, 425]]], dtype=int32), array([[[124, 423]],
#
#         [[123, 424]],
#
#         [[123, 425]],
#
#         [[123, 424]],
#
#         [[124, 423]],
#
#         [[125, 424]],
#
#         [[125, 425]],
#
#         [[125, 424]]], dtype=int32), array([[[204, 422]]], dtype=int32), array([[[262, 421]],
#
#         [[262, 422]],
#
#         [[262, 423]],
#
#         [[263, 423]],
#
#         [[264, 423]],
#
#         [[264, 422]],
#
#         [[264, 421]],
#
#         [[263, 421]]], dtype=int32), array([[[143, 419]],
#
#         [[143, 420]],
#
#         [[143, 421]],
#
#         [[144, 421]],
#
#         [[145, 421]],
#
#         [[145, 420]],
#
#         [[145, 419]],
#
#         [[144, 419]]], dtype=int32), array([[[111, 416]],
#
#         [[111, 417]],
#
#         [[111, 418]],
#
#         [[112, 418]],
#
#         [[113, 418]],
#
#         [[113, 417]],
#
#         [[113, 416]],
#
#         [[112, 416]]], dtype=int32), array([[[290, 414]],
#
#         [[290, 415]],
#
#         [[290, 416]],
#
#         [[291, 416]],
#
#         [[290, 415]],
#
#         [[291, 414]],
#
#         [[292, 414]],
#
#         [[293, 415]],
#
#         [[293, 416]],
#
#         [[293, 417]],
#
#         [[293, 416]],
#
#         [[294, 415]],
#
#         [[293, 415]],
#
#         [[292, 414]],
#
#         [[291, 414]]], dtype=int32), array([[[114, 414]],
#
#         [[115, 414]],
#
#         [[116, 415]],
#
#         [[115, 416]],
#
#         [[116, 416]],
#
#         [[116, 415]],
#
#         [[116, 414]],
#
#         [[115, 414]]], dtype=int32), array([[[103, 414]],
#
#         [[103, 415]],
#
#         [[103, 416]],
#
#         [[104, 416]],
#
#         [[105, 416]],
#
#         [[105, 415]],
#
#         [[104, 414]]], dtype=int32), array([[[152, 412]],
#
#         [[152, 413]],
#
#         [[152, 414]],
#
#         [[153, 414]],
#
#         [[154, 414]],
#
#         [[154, 413]],
#
#         [[154, 412]],
#
#         [[153, 412]]], dtype=int32), array([[[218, 410]],
#
#         [[218, 411]],
#
#         [[218, 412]],
#
#         [[219, 412]],
#
#         [[220, 411]],
#
#         [[219, 410]]], dtype=int32), array([[[107, 410]],
#
#         [[106, 411]],
#
#         [[106, 412]],
#
#         [[106, 413]],
#
#         [[107, 413]],
#
#         [[108, 413]],
#
#         [[108, 412]],
#
#         [[108, 411]]], dtype=int32), array([[[110, 405]],
#
#         [[110, 406]],
#
#         [[110, 407]],
#
#         [[111, 407]],
#
#         [[112, 407]],
#
#         [[112, 406]],
#
#         [[112, 405]],
#
#         [[111, 405]]], dtype=int32), array([[[303, 401]],
#
#         [[304, 401]]], dtype=int32), array([[[303, 399]],
#
#         [[304, 399]]], dtype=int32), array([[[300, 398]],
#
#         [[299, 399]],
#
#         [[300, 400]],
#
#         [[301, 400]],
#
#         [[300, 400]],
#
#         [[299, 399]],
#
#         [[300, 398]],
#
#         [[301, 398]]], dtype=int32), array([[[221, 398]],
#
#         [[220, 399]],
#
#         [[221, 398]],
#
#         [[222, 398]],
#
#         [[223, 398]],
#
#         [[224, 398]],
#
#         [[225, 399]],
#
#         [[224, 400]],
#
#         [[223, 400]],
#
#         [[222, 400]],
#
#         [[221, 401]],
#
#         [[221, 402]],
#
#         [[220, 403]],
#
#         [[219, 402]],
#
#         [[219, 401]],
#
#         [[219, 402]],
#
#         [[219, 403]],
#
#         [[220, 403]],
#
#         [[221, 403]],
#
#         [[221, 402]],
#
#         [[221, 401]],
#
#         [[222, 400]],
#
#         [[223, 400]],
#
#         [[224, 400]],
#
#         [[225, 400]],
#
#         [[225, 399]],
#
#         [[225, 398]],
#
#         [[224, 398]],
#
#         [[223, 398]],
#
#         [[222, 398]]], dtype=int32), array([[[146, 398]],
#
#         [[145, 399]]], dtype=int32), array([[[146, 393]],
#
#         [[146, 394]],
#
#         [[146, 395]],
#
#         [[146, 394]],
#
#         [[147, 393]]], dtype=int32), array([[[254, 391]],
#
#         [[253, 392]],
#
#         [[254, 393]],
#
#         [[255, 393]],
#
#         [[254, 393]],
#
#         [[253, 392]],
#
#         [[254, 391]],
#
#         [[255, 391]]], dtype=int32), array([[[222, 391]],
#
#         [[222, 392]],
#
#         [[222, 393]],
#
#         [[222, 394]],
#
#         [[223, 393]],
#
#         [[224, 393]],
#
#         [[223, 393]],
#
#         [[222, 392]]], dtype=int32), array([[[249, 390]],
#
#         [[248, 391]],
#
#         [[248, 392]],
#
#         [[249, 392]],
#
#         [[250, 392]],
#
#         [[250, 391]],
#
#         [[250, 390]]], dtype=int32), array([[[227, 390]]], dtype=int32), array([[[224, 389]],
#
#         [[225, 389]]], dtype=int32), array([[[233, 388]],
#
#         [[233, 389]],
#
#         [[234, 388]]], dtype=int32), array([[[217, 386]]], dtype=int32), array([[[245, 385]],
#
#         [[246, 386]],
#
#         [[247, 387]],
#
#         [[246, 386]]], dtype=int32), array([[[216, 384]],
#
#         [[215, 385]],
#
#         [[215, 386]],
#
#         [[215, 385]],
#
#         [[216, 384]],
#
#         [[217, 384]]], dtype=int32), array([[[243, 383]],
#
#         [[242, 384]],
#
#         [[243, 385]],
#
#         [[243, 386]],
#
#         [[244, 387]],
#
#         [[243, 386]],
#
#         [[243, 385]],
#
#         [[242, 384]]], dtype=int32), array([[[122, 383]],
#
#         [[122, 384]],
#
#         [[122, 385]],
#
#         [[123, 385]],
#
#         [[124, 385]],
#
#         [[124, 384]],
#
#         [[124, 383]],
#
#         [[123, 383]]], dtype=int32), array([[[235, 382]],
#
#         [[235, 383]],
#
#         [[235, 384]],
#
#         [[236, 384]],
#
#         [[237, 384]],
#
#         [[238, 384]],
#
#         [[239, 384]],
#
#         [[240, 384]],
#
#         [[240, 383]],
#
#         [[240, 382]],
#
#         [[239, 382]],
#
#         [[238, 382]],
#
#         [[237, 382]],
#
#         [[236, 382]]], dtype=int32), array([[[135, 382]],
#
#         [[135, 383]],
#
#         [[134, 384]],
#
#         [[134, 385]],
#
#         [[134, 386]],
#
#         [[134, 387]],
#
#         [[134, 388]],
#
#         [[135, 388]],
#
#         [[136, 387]],
#
#         [[136, 386]],
#
#         [[137, 385]],
#
#         [[137, 384]],
#
#         [[137, 383]],
#
#         [[137, 382]],
#
#         [[136, 382]]], dtype=int32), array([[[254, 378]],
#
#         [[255, 378]],
#
#         [[256, 378]],
#
#         [[257, 378]],
#
#         [[258, 379]],
#
#         [[257, 380]],
#
#         [[256, 380]],
#
#         [[255, 380]],
#
#         [[254, 380]],
#
#         [[255, 380]],
#
#         [[256, 380]],
#
#         [[257, 380]],
#
#         [[258, 381]],
#
#         [[259, 381]],
#
#         [[260, 381]],
#
#         [[261, 382]],
#
#         [[262, 382]],
#
#         [[263, 382]],
#
#         [[264, 381]],
#
#         [[265, 381]],
#
#         [[264, 380]],
#
#         [[263, 380]],
#
#         [[262, 379]],
#
#         [[261, 379]],
#
#         [[260, 379]],
#
#         [[259, 379]],
#
#         [[258, 379]],
#
#         [[257, 378]],
#
#         [[256, 378]],
#
#         [[255, 378]]], dtype=int32), array([[[118, 378]],
#
#         [[118, 379]],
#
#         [[118, 380]],
#
#         [[119, 380]],
#
#         [[120, 380]],
#
#         [[120, 379]],
#
#         [[120, 378]],
#
#         [[119, 378]]], dtype=int32), array([[[243, 373]],
#
#         [[243, 374]],
#
#         [[243, 375]],
#
#         [[244, 376]],
#
#         [[245, 377]],
#
#         [[246, 377]],
#
#         [[247, 378]],
#
#         [[248, 378]],
#
#         [[249, 378]],
#
#         [[248, 378]],
#
#         [[247, 378]],
#
#         [[246, 377]],
#
#         [[245, 376]],
#
#         [[244, 376]],
#
#         [[243, 375]],
#
#         [[243, 374]],
#
#         [[244, 373]],
#
#         [[245, 374]],
#
#         [[246, 374]],
#
#         [[247, 374]],
#
#         [[248, 375]],
#
#         [[249, 376]],
#
#         [[250, 376]],
#
#         [[251, 377]],
#
#         [[251, 378]],
#
#         [[251, 377]],
#
#         [[250, 376]],
#
#         [[249, 375]],
#
#         [[248, 375]],
#
#         [[247, 374]],
#
#         [[246, 374]],
#
#         [[245, 374]],
#
#         [[244, 373]]], dtype=int32), array([[[225, 373]],
#
#         [[225, 374]],
#
#         [[225, 375]],
#
#         [[226, 375]],
#
#         [[227, 375]],
#
#         [[227, 374]],
#
#         [[227, 373]],
#
#         [[226, 373]]], dtype=int32), array([[[262, 370]],
#
#         [[263, 370]]], dtype=int32), array([[[239, 370]],
#
#         [[238, 371]],
#
#         [[238, 372]],
#
#         [[238, 371]],
#
#         [[239, 370]],
#
#         [[240, 371]],
#
#         [[240, 372]],
#
#         [[240, 371]]], dtype=int32), array([[[233, 369]],
#
#         [[233, 370]],
#
#         [[233, 371]],
#
#         [[234, 371]],
#
#         [[235, 371]],
#
#         [[235, 370]],
#
#         [[235, 369]],
#
#         [[234, 369]]], dtype=int32), array([[[270, 367]]], dtype=int32), array([[[255, 364]],
#
#         [[254, 365]],
#
#         [[255, 366]],
#
#         [[255, 367]],
#
#         [[256, 367]],
#
#         [[257, 368]],
#
#         [[258, 369]],
#
#         [[259, 369]],
#
#         [[258, 368]],
#
#         [[257, 368]],
#
#         [[256, 367]],
#
#         [[255, 366]],
#
#         [[254, 365]],
#
#         [[255, 364]],
#
#         [[256, 364]],
#
#         [[257, 364]],
#
#         [[258, 364]],
#
#         [[259, 365]],
#
#         [[259, 366]],
#
#         [[260, 367]],
#
#         [[261, 368]],
#
#         [[262, 368]],
#
#         [[263, 368]],
#
#         [[262, 368]],
#
#         [[261, 368]],
#
#         [[260, 367]],
#
#         [[259, 366]],
#
#         [[259, 365]],
#
#         [[258, 364]],
#
#         [[257, 364]],
#
#         [[256, 364]]], dtype=int32), array([[[266, 363]],
#
#         [[265, 364]],
#
#         [[266, 365]],
#
#         [[267, 365]],
#
#         [[268, 366]],
#
#         [[268, 367]],
#
#         [[268, 366]],
#
#         [[268, 365]],
#
#         [[267, 365]],
#
#         [[266, 365]],
#
#         [[265, 364]],
#
#         [[266, 363]],
#
#         [[267, 363]],
#
#         [[268, 363]],
#
#         [[269, 363]],
#
#         [[270, 364]],
#
#         [[270, 365]],
#
#         [[271, 365]],
#
#         [[270, 364]],
#
#         [[269, 363]],
#
#         [[268, 363]],
#
#         [[267, 363]]], dtype=int32), array([[[229, 358]],
#
#         [[229, 359]],
#
#         [[229, 360]],
#
#         [[230, 360]],
#
#         [[231, 360]],
#
#         [[231, 359]],
#
#         [[231, 358]],
#
#         [[230, 358]]], dtype=int32), array([[[211, 347]],
#
#         [[211, 348]]], dtype=int32), array([[[208, 343]],
#
#         [[208, 344]],
#
#         [[208, 345]],
#
#         [[209, 346]],
#
#         [[209, 347]],
#
#         [[209, 348]],
#
#         [[209, 347]],
#
#         [[209, 346]],
#
#         [[208, 345]],
#
#         [[208, 344]],
#
#         [[209, 343]],
#
#         [[210, 344]],
#
#         [[210, 343]],
#
#         [[209, 343]]], dtype=int32), array([[[262, 342]]], dtype=int32), array([[[260, 342]]], dtype=int32), array([[[262, 340]]], dtype=int32), array([[[260, 340]]], dtype=int32), array([[[135, 330]],
#
#         [[134, 331]],
#
#         [[134, 332]],
#
#         [[134, 331]],
#
#         [[135, 330]],
#
#         [[136, 331]],
#
#         [[136, 332]],
#
#         [[136, 331]]], dtype=int32), array([[[138, 327]],
#
#         [[137, 328]],
#
#         [[138, 329]],
#
#         [[139, 329]],
#
#         [[138, 329]],
#
#         [[137, 328]],
#
#         [[138, 327]],
#
#         [[139, 327]]], dtype=int32), array([[[245, 324]],
#
#         [[244, 325]],
#
#         [[245, 326]],
#
#         [[246, 326]],
#
#         [[245, 326]],
#
#         [[244, 325]],
#
#         [[245, 324]],
#
#         [[246, 324]]], dtype=int32), array([[[251, 323]],
#
#         [[250, 324]],
#
#         [[251, 325]],
#
#         [[252, 325]],
#
#         [[251, 325]],
#
#         [[250, 324]],
#
#         [[251, 323]],
#
#         [[252, 323]]], dtype=int32), array([[[178, 322]],
#
#         [[177, 323]],
#
#         [[177, 324]],
#
#         [[177, 325]],
#
#         [[178, 325]],
#
#         [[179, 325]],
#
#         [[179, 324]],
#
#         [[179, 323]]], dtype=int32), array([[[195, 311]],
#
#         [[195, 312]],
#
#         [[195, 313]],
#
#         [[196, 313]],
#
#         [[197, 313]],
#
#         [[197, 312]],
#
#         [[197, 311]],
#
#         [[196, 311]]], dtype=int32), array([[[182, 309]],
#
#         [[181, 310]],
#
#         [[181, 311]],
#
#         [[181, 312]],
#
#         [[181, 313]],
#
#         [[181, 312]],
#
#         [[181, 311]],
#
#         [[181, 310]],
#
#         [[182, 309]],
#
#         [[183, 310]],
#
#         [[183, 311]],
#
#         [[183, 312]],
#
#         [[183, 311]],
#
#         [[183, 310]]], dtype=int32), array([[[242, 303]],
#
#         [[242, 304]],
#
#         [[242, 305]],
#
#         [[243, 305]],
#
#         [[244, 305]],
#
#         [[244, 304]],
#
#         [[244, 303]],
#
#         [[243, 303]]], dtype=int32), array([[[222, 302]],
#
#         [[223, 303]]], dtype=int32), array([[[224, 300]]], dtype=int32), array([[[222, 300]]], dtype=int32), array([[[256, 295]],
#
#         [[257, 295]]], dtype=int32), array([[[254, 293]],
#
#         [[254, 294]],
#
#         [[255, 293]],
#
#         [[256, 293]],
#
#         [[257, 293]],
#
#         [[256, 293]],
#
#         [[255, 293]]], dtype=int32), array([[[218, 283]],
#
#         [[218, 284]],
#
#         [[218, 285]],
#
#         [[219, 285]],
#
#         [[220, 285]],
#
#         [[220, 284]],
#
#         [[219, 283]]], dtype=int32), array([[[221, 281]],
#
#         [[221, 282]],
#
#         [[222, 281]]], dtype=int32), array([[[228, 279]],
#
#         [[228, 280]],
#
#         [[228, 281]],
#
#         [[229, 281]],
#
#         [[230, 281]],
#
#         [[230, 280]],
#
#         [[229, 279]]], dtype=int32), array([[[234, 278]],
#
#         [[235, 278]],
#
#         [[236, 278]],
#
#         [[235, 278]]], dtype=int32), array([[[216, 278]],
#
#         [[215, 279]],
#
#         [[216, 280]],
#
#         [[217, 280]],
#
#         [[216, 280]],
#
#         [[215, 279]],
#
#         [[216, 278]],
#
#         [[217, 278]]], dtype=int32), array([[[202, 278]],
#
#         [[202, 279]],
#
#         [[202, 280]],
#
#         [[203, 280]],
#
#         [[204, 280]],
#
#         [[204, 279]],
#
#         [[204, 278]],
#
#         [[203, 278]]], dtype=int32), array([[[231, 276]],
#
#         [[231, 277]],
#
#         [[232, 276]],
#
#         [[233, 276]],
#
#         [[234, 276]],
#
#         [[235, 276]],
#
#         [[236, 276]],
#
#         [[237, 276]],
#
#         [[236, 276]],
#
#         [[235, 276]],
#
#         [[234, 276]],
#
#         [[233, 276]],
#
#         [[232, 276]]], dtype=int32), array([[[161, 274]],
#
#         [[160, 275]],
#
#         [[161, 276]],
#
#         [[162, 276]],
#
#         [[161, 276]],
#
#         [[160, 275]],
#
#         [[161, 274]],
#
#         [[162, 274]]], dtype=int32), array([[[149, 274]],
#
#         [[148, 275]],
#
#         [[147, 276]],
#
#         [[147, 277]],
#
#         [[147, 276]],
#
#         [[148, 275]],
#
#         [[149, 274]],
#
#         [[150, 274]],
#
#         [[151, 275]],
#
#         [[150, 276]],
#
#         [[149, 277]],
#
#         [[150, 276]],
#
#         [[151, 276]],
#
#         [[151, 275]],
#
#         [[150, 274]]], dtype=int32), array([[[243, 273]],
#
#         [[243, 274]],
#
#         [[243, 275]],
#
#         [[244, 275]],
#
#         [[245, 275]],
#
#         [[245, 274]],
#
#         [[245, 273]],
#
#         [[244, 273]]], dtype=int32), array([[[138, 273]],
#
#         [[137, 274]],
#
#         [[137, 275]],
#
#         [[137, 274]],
#
#         [[138, 273]],
#
#         [[139, 274]],
#
#         [[139, 275]],
#
#         [[139, 274]]], dtype=int32), array([[[148, 269]],
#
#         [[148, 270]],
#
#         [[148, 271]],
#
#         [[149, 271]],
#
#         [[150, 271]],
#
#         [[150, 270]],
#
#         [[150, 269]],
#
#         [[149, 269]]], dtype=int32), array([[[121, 268]],
#
#         [[121, 269]],
#
#         [[121, 270]],
#
#         [[122, 270]],
#
#         [[123, 270]],
#
#         [[123, 269]],
#
#         [[123, 268]],
#
#         [[122, 268]]], dtype=int32), array([[[154, 266]],
#
#         [[153, 267]],
#
#         [[153, 268]],
#
#         [[153, 269]],
#
#         [[153, 270]],
#
#         [[152, 271]],
#
#         [[152, 272]],
#
#         [[152, 273]],
#
#         [[153, 274]],
#
#         [[154, 274]],
#
#         [[155, 273]],
#
#         [[155, 272]],
#
#         [[155, 271]],
#
#         [[155, 270]],
#
#         [[155, 269]],
#
#         [[155, 268]],
#
#         [[155, 267]]], dtype=int32), array([[[115, 264]]], dtype=int32), array([[[258, 263]],
#
#         [[258, 264]],
#
#         [[259, 263]],
#
#         [[260, 263]],
#
#         [[261, 263]],
#
#         [[262, 264]],
#
#         [[261, 265]],
#
#         [[260, 265]],
#
#         [[261, 265]],
#
#         [[262, 265]],
#
#         [[262, 264]],
#
#         [[262, 263]],
#
#         [[261, 263]],
#
#         [[260, 263]],
#
#         [[259, 263]]], dtype=int32), array([[[159, 263]],
#
#         [[158, 264]],
#
#         [[158, 265]],
#
#         [[158, 266]],
#
#         [[158, 267]],
#
#         [[159, 267]],
#
#         [[160, 266]],
#
#         [[160, 265]],
#
# ...
#
#         [[256,  83]],
#
#         [[255,  84]],
#
#         [[256,  85]],
#
#         [[257,  85]],
#
#         [[258,  84]],
#
#         [[257,  83]],
#
#         [[258,  82]],
#
#         [[259,  82]]], dtype=int32), array([[[276,  79]],
#
#         [[275,  80]],
#
#         [[274,  80]],
#
#         [[273,  80]],
#
#         [[272,  80]],
#
#         [[271,  81]],
#
#         [[270,  80]],
#
#         [[269,  81]],
#
#         [[268,  80]],
#
#         [[267,  80]],
#
#         [[266,  81]],
#
#         [[266,  82]],
#
#         [[266,  81]],
#
#         [[267,  80]],
#
#         [[268,  80]],
#
#         [[269,  81]],
#
#         [[269,  82]],
#
#         [[269,  81]],
#
#         [[270,  80]],
#
#         [[271,  81]],
#
#         [[271,  82]],
#
#         [[271,  83]],
#
#         [[272,  84]],
#
#         [[272,  85]],
#
#         [[272,  86]],
#
#         [[272,  87]],
#
#         [[272,  88]],
#
#         [[271,  89]],
#
#         [[270,  89]],
#
#         [[269,  90]],
#
#         [[269,  91]],
#
#         [[269,  90]],
#
#         [[270,  89]],
#
#         [[271,  89]],
#
#         [[272,  88]],
#
#         [[272,  87]],
#
#         [[272,  86]],
#
#         [[272,  85]],
#
#         [[272,  84]],
#
#         [[272,  83]],
#
#         [[271,  82]],
#
#         [[271,  81]],
#
#         [[272,  80]],
#
#         [[273,  80]],
#
#         [[274,  80]],
#
#         [[275,  80]],
#
#         [[276,  79]],
#
#         [[277,  79]],
#
#         [[278,  79]],
#
#         [[279,  80]],
#
#         [[279,  81]],
#
#         [[279,  82]],
#
#         [[278,  83]],
#
#         [[278,  84]],
#
#         [[278,  85]],
#
#         [[277,  86]],
#
#         [[276,  86]],
#
#         [[275,  87]],
#
#         [[275,  88]],
#
#         [[274,  89]],
#
#         [[273,  90]],
#
#         [[274,  90]],
#
#         [[274,  89]],
#
#         [[275,  88]],
#
#         [[276,  87]],
#
#         [[277,  86]],
#
#         [[278,  85]],
#
#         [[278,  84]],
#
#         [[278,  83]],
#
#         [[279,  82]],
#
#         [[279,  81]],
#
#         [[279,  80]],
#
#         [[279,  79]],
#
#         [[278,  79]],
#
#         [[277,  79]]], dtype=int32), array([[[262,  79]],
#
#         [[262,  80]],
#
#         [[262,  81]],
#
#         [[263,  81]],
#
#         [[264,  80]],
#
#         [[264,  79]],
#
#         [[263,  79]]], dtype=int32), array([[[250,  78]]], dtype=int32), array([[[248,  78]],
#
#         [[248,  79]]], dtype=int32), array([[[75, 78]],
#
#         [[74, 79]],
#
#         [[73, 79]],
#
#         [[72, 79]],
#
#         [[71, 79]],
#
#         [[70, 79]],
#
#         [[69, 80]],
#
#         [[68, 81]],
#
#         [[69, 82]],
#
#         [[69, 83]],
#
#         [[70, 83]],
#
#         [[71, 83]],
#
#         [[72, 83]],
#
#         [[73, 83]],
#
#         [[74, 83]],
#
#         [[75, 82]],
#
#         [[76, 81]],
#
#         [[77, 82]],
#
#         [[78, 82]],
#
#         [[79, 82]],
#
#         [[80, 81]],
#
#         [[81, 81]],
#
#         [[80, 81]],
#
#         [[79, 81]],
#
#         [[78, 82]],
#
#         [[77, 82]],
#
#         [[76, 81]],
#
#         [[75, 82]],
#
#         [[74, 82]],
#
#         [[73, 83]],
#
#         [[72, 83]],
#
#         [[71, 83]],
#
#         [[70, 83]],
#
#         [[69, 82]],
#
#         [[68, 81]],
#
#         [[69, 80]],
#
#         [[70, 79]],
#
#         [[71, 79]],
#
#         [[72, 79]],
#
#         [[73, 79]],
#
#         [[74, 79]],
#
#         [[75, 78]],
#
#         [[76, 78]],
#
#         [[77, 78]],
#
#         [[78, 79]],
#
#         [[79, 79]],
#
#         [[80, 79]],
#
#         [[81, 79]],
#
#         [[82, 79]],
#
#         [[83, 79]],
#
#         [[84, 79]],
#
#         [[85, 79]],
#
#         [[86, 79]],
#
#         [[87, 80]],
#
#         [[86, 81]],
#
#         [[85, 81]],
#
#         [[84, 81]],
#
#         [[83, 81]],
#
#         [[84, 81]],
#
#         [[85, 81]],
#
#         [[86, 81]],
#
#         [[87, 81]],
#
#         [[87, 80]],
#
#         [[87, 79]],
#
#         [[86, 79]],
#
#         [[85, 79]],
#
#         [[84, 79]],
#
#         [[83, 79]],
#
#         [[82, 79]],
#
#         [[81, 79]],
#
#         [[80, 79]],
#
#         [[79, 79]],
#
#         [[78, 79]],
#
#         [[77, 78]],
#
#         [[76, 78]]], dtype=int32), array([[[254,  77]],
#
#         [[255,  77]]], dtype=int32), array([[[102,  77]],
#
#         [[102,  78]],
#
#         [[103,  79]],
#
#         [[104,  79]],
#
#         [[105,  79]],
#
#         [[106,  79]],
#
#         [[107,  79]],
#
#         [[107,  78]],
#
#         [[107,  77]],
#
#         [[106,  77]],
#
#         [[105,  77]],
#
#         [[104,  77]],
#
#         [[103,  77]]], dtype=int32), array([[[55, 75]],
#
#         [[54, 76]],
#
#         [[55, 77]],
#
#         [[55, 78]],
#
#         [[56, 78]],
#
#         [[57, 79]],
#
#         [[58, 79]],
#
#         [[59, 79]],
#
#         [[60, 78]],
#
#         [[61, 78]],
#
#         [[60, 77]],
#
#         [[59, 76]],
#
#         [[58, 75]],
#
#         [[57, 75]],
#
#         [[58, 76]],
#
#         [[59, 77]],
#
#         [[60, 78]],
#
#         [[59, 79]],
#
#         [[58, 79]],
#
#         [[57, 79]],
#
#         [[56, 78]],
#
#         [[55, 77]],
#
#         [[54, 76]]], dtype=int32), array([[[263,  74]],
#
#         [[263,  75]],
#
#         [[263,  76]],
#
#         [[264,  76]],
#
#         [[263,  75]],
#
#         [[264,  74]],
#
#         [[265,  74]],
#
#         [[266,  74]],
#
#         [[267,  74]],
#
#         [[268,  74]],
#
#         [[269,  75]],
#
#         [[269,  76]],
#
#         [[268,  77]],
#
#         [[267,  77]],
#
#         [[266,  77]],
#
#         [[267,  77]],
#
#         [[268,  77]],
#
#         [[269,  77]],
#
#         [[269,  76]],
#
#         [[269,  75]],
#
#         [[268,  74]],
#
#         [[267,  74]],
#
#         [[266,  74]],
#
#         [[265,  74]],
#
#         [[264,  74]]], dtype=int32), array([[[56, 72]]], dtype=int32), array([[[266,  69]],
#
#         [[265,  70]],
#
#         [[266,  71]],
#
#         [[267,  71]],
#
#         [[268,  71]],
#
#         [[269,  71]],
#
#         [[270,  71]],
#
#         [[271,  71]],
#
#         [[271,  70]],
#
#         [[271,  69]],
#
#         [[270,  69]],
#
#         [[269,  69]],
#
#         [[268,  69]],
#
#         [[267,  69]]], dtype=int32), array([[[121,  69]],
#
#         [[122,  70]],
#
#         [[123,  71]],
#
#         [[124,  72]],
#
#         [[125,  73]],
#
#         [[126,  73]],
#
#         [[127,  74]],
#
#         [[128,  75]],
#
#         [[129,  76]],
#
#         [[129,  77]],
#
#         [[130,  78]],
#
#         [[131,  79]],
#
#         [[132,  79]],
#
#         [[133,  79]],
#
#         [[133,  78]],
#
#         [[133,  77]],
#
#         [[133,  76]],
#
#         [[133,  75]],
#
#         [[132,  75]],
#
#         [[131,  74]],
#
#         [[130,  73]],
#
#         [[129,  72]],
#
#         [[130,  73]],
#
#         [[131,  74]],
#
#         [[132,  75]],
#
#         [[133,  76]],
#
#         [[133,  77]],
#
#         [[133,  78]],
#
#         [[132,  79]],
#
#         [[131,  79]],
#
#         [[130,  78]],
#
#         [[129,  77]],
#
#         [[129,  76]],
#
#         [[128,  75]],
#
#         [[128,  74]],
#
#         [[127,  74]],
#
#         [[126,  73]],
#
#         [[125,  72]],
#
#         [[124,  71]],
#
#         [[123,  71]],
#
#         [[122,  70]]], dtype=int32), array([[[185,  68]],
#
#         [[185,  69]],
#
#         [[185,  70]],
#
#         [[186,  70]],
#
#         [[187,  70]],
#
#         [[187,  69]],
#
#         [[187,  68]],
#
#         [[186,  68]]], dtype=int32), array([[[124,  68]],
#
#         [[125,  69]],
#
#         [[126,  70]],
#
#         [[127,  70]],
#
#         [[128,  70]],
#
#         [[129,  70]],
#
#         [[128,  70]],
#
#         [[127,  70]],
#
#         [[126,  70]],
#
#         [[125,  69]]], dtype=int32), array([[[243,  67]],
#
#         [[242,  68]],
#
#         [[243,  69]],
#
#         [[244,  69]],
#
#         [[243,  69]],
#
#         [[242,  68]],
#
#         [[243,  67]],
#
#         [[244,  67]]], dtype=int32), array([[[275,  66]],
#
#         [[274,  67]],
#
#         [[273,  67]],
#
#         [[273,  68]],
#
#         [[274,  69]],
#
#         [[275,  69]],
#
#         [[276,  69]],
#
#         [[277,  69]],
#
#         [[277,  68]],
#
#         [[277,  67]],
#
#         [[276,  67]]], dtype=int32), array([[[237,  65]],
#
#         [[236,  66]],
#
#         [[235,  67]],
#
#         [[236,  68]],
#
#         [[237,  68]],
#
#         [[238,  67]],
#
#         [[237,  68]],
#
#         [[236,  68]],
#
#         [[235,  67]],
#
#         [[236,  66]],
#
#         [[237,  65]],
#
#         [[238,  65]]], dtype=int32), array([[[104,  65]],
#
#         [[104,  66]],
#
#         [[104,  67]],
#
#         [[105,  67]],
#
#         [[106,  67]],
#
#         [[106,  66]],
#
#         [[106,  65]],
#
#         [[105,  65]]], dtype=int32), array([[[55, 65]],
#
#         [[54, 66]],
#
#         [[54, 67]],
#
#         [[54, 68]],
#
#         [[54, 69]],
#
#         [[54, 70]],
#
#         [[54, 71]],
#
#         [[54, 70]],
#
#         [[54, 69]],
#
#         [[54, 68]],
#
#         [[54, 67]],
#
#         [[54, 66]],
#
#         [[55, 65]],
#
#         [[56, 66]],
#
#         [[56, 67]],
#
#         [[56, 68]],
#
#         [[56, 69]],
#
#         [[56, 70]],
#
#         [[56, 69]],
#
#         [[56, 68]],
#
#         [[56, 67]],
#
#         [[56, 66]]], dtype=int32), array([[[115,  64]],
#
#         [[115,  65]],
#
#         [[115,  66]],
#
#         [[116,  66]],
#
#         [[117,  67]],
#
#         [[118,  67]],
#
#         [[119,  68]],
#
#         [[118,  67]],
#
#         [[117,  67]],
#
#         [[116,  66]],
#
#         [[115,  65]],
#
#         [[116,  64]],
#
#         [[117,  64]],
#
#         [[118,  64]],
#
#         [[119,  65]],
#
#         [[120,  66]],
#
#         [[121,  66]],
#
#         [[122,  67]],
#
#         [[121,  66]],
#
#         [[120,  65]],
#
#         [[119,  65]],
#
#         [[118,  64]],
#
#         [[117,  64]],
#
#         [[116,  64]]], dtype=int32), array([[[277,  63]]], dtype=int32), array([[[275,  63]]], dtype=int32), array([[[277,  61]]], dtype=int32), array([[[275,  61]]], dtype=int32), array([[[264,  60]],
#
#         [[265,  60]]], dtype=int32), array([[[258,  59]],
#
#         [[257,  60]],
#
#         [[258,  61]],
#
#         [[259,  61]],
#
#         [[260,  61]],
#
#         [[261,  61]],
#
#         [[261,  60]],
#
#         [[261,  59]],
#
#         [[260,  59]],
#
#         [[259,  59]]], dtype=int32), array([[[56, 59]],
#
#         [[55, 60]],
#
#         [[56, 61]],
#
#         [[57, 61]],
#
#         [[56, 61]],
#
#         [[55, 60]],
#
#         [[56, 59]],
#
#         [[57, 59]]], dtype=int32), array([[[271,  58]]], dtype=int32), array([[[269,  58]]], dtype=int32), array([[[246,  58]],
#
#         [[245,  59]],
#
#         [[244,  59]],
#
#         [[243,  59]],
#
#         [[242,  60]],
#
#         [[243,  61]],
#
#         [[244,  61]],
#
#         [[243,  61]],
#
#         [[242,  60]],
#
#         [[243,  59]],
#
#         [[244,  59]],
#
#         [[245,  59]],
#
#         [[246,  58]],
#
#         [[247,  58]],
#
#         [[248,  58]],
#
#         [[249,  58]],
#
#         [[250,  59]],
#
#         [[249,  60]],
#
#         [[248,  60]],
#
#         [[249,  60]],
#
#         [[250,  59]],
#
#         [[250,  58]],
#
#         [[249,  58]],
#
#         [[248,  58]],
#
#         [[247,  58]]], dtype=int32), array([[[267,  57]]], dtype=int32), array([[[226,  57]]], dtype=int32), array([[[270,  56]],
#
#         [[271,  56]]], dtype=int32), array([[[266,  55]],
#
#         [[265,  56]],
#
#         [[265,  57]],
#
#         [[264,  58]],
#
#         [[265,  57]],
#
#         [[265,  56]],
#
#         [[266,  55]],
#
#         [[267,  55]]], dtype=int32), array([[[257,  55]],
#
#         [[256,  56]],
#
#         [[257,  57]],
#
#         [[258,  57]],
#
#         [[257,  57]],
#
#         [[256,  56]],
#
#         [[257,  55]],
#
#         [[258,  55]],
#
#         [[259,  55]],
#
#         [[258,  55]]], dtype=int32), array([[[226,  55]],
#
#         [[227,  55]]], dtype=int32), array([[[214,  55]],
#
#         [[213,  56]]], dtype=int32), array([[[55, 54]],
#
#         [[55, 55]],
#
#         [[55, 56]],
#
#         [[56, 56]],
#
#         [[55, 55]],
#
#         [[56, 54]],
#
#         [[57, 54]],
#
#         [[56, 54]]], dtype=int32), array([[[240,  53]],
#
#         [[239,  54]],
#
#         [[240,  55]],
#
#         [[241,  55]],
#
#         [[242,  55]],
#
#         [[243,  55]],
#
#         [[243,  54]],
#
#         [[243,  53]],
#
#         [[242,  53]],
#
#         [[241,  53]]], dtype=int32), array([[[245,  52]],
#
#         [[246,  52]],
#
#         [[247,  53]],
#
#         [[246,  54]],
#
#         [[245,  54]],
#
#         [[246,  54]],
#
#         [[247,  54]],
#
#         [[247,  53]],
#
#         [[247,  52]],
#
#         [[246,  52]]], dtype=int32), array([[[281,  51]],
#
#         [[281,  52]],
#
#         [[281,  53]],
#
#         [[282,  53]],
#
#         [[283,  53]],
#
#         [[283,  52]],
#
#         [[283,  51]],
#
#         [[282,  51]]], dtype=int32), array([[[214,  50]],
#
#         [[213,  51]],
#
#         [[213,  52]],
#
#         [[213,  53]],
#
#         [[212,  54]],
#
#         [[211,  55]],
#
#         [[210,  55]],
#
#         [[210,  56]],
#
#         [[210,  57]],
#
#         [[210,  58]],
#
#         [[211,  59]],
#
#         [[212,  59]],
#
#         [[211,  59]],
#
#         [[210,  58]],
#
#         [[210,  57]],
#
#         [[210,  56]],
#
#         [[211,  55]],
#
#         [[212,  54]],
#
#         [[213,  53]],
#
#         [[213,  52]],
#
#         [[213,  51]],
#
#         [[214,  50]],
#
#         [[215,  50]],
#
#         [[216,  51]],
#
#         [[215,  52]],
#
#         [[215,  53]],
#
#         [[215,  52]],
#
#         [[216,  51]],
#
#         [[217,  51]],
#
#         [[216,  51]],
#
#         [[215,  50]]], dtype=int32), array([[[217,  49]]], dtype=int32), array([[[246,  48]],
#
#         [[245,  49]],
#
#         [[246,  50]],
#
#         [[247,  50]],
#
#         [[246,  50]],
#
#         [[245,  49]],
#
#         [[246,  48]],
#
#         [[247,  48]]], dtype=int32), array([[[258,  46]],
#
#         [[258,  47]],
#
#         [[258,  48]],
#
#         [[259,  48]],
#
#         [[260,  48]],
#
#         [[260,  47]],
#
#         [[260,  46]],
#
#         [[259,  46]]], dtype=int32), array([[[227,  45]],
#
#         [[227,  46]],
#
#         [[227,  47]],
#
#         [[228,  47]],
#
#         [[229,  47]],
#
#         [[229,  46]],
#
#         [[229,  45]],
#
#         [[228,  45]]], dtype=int32), array([[[218,  45]],
#
#         [[218,  46]],
#
#         [[218,  47]],
#
#         [[219,  47]],
#
#         [[220,  46]],
#
#         [[219,  45]]], dtype=int32), array([[[55, 40]],
#
#         [[55, 41]],
#
#         [[55, 42]],
#
#         [[56, 42]],
#
#         [[57, 42]],
#
#         [[57, 41]],
#
#         [[57, 40]],
#
#         [[56, 40]]], dtype=int32), array([[[279,  37]],
#
#         [[278,  38]]], dtype=int32), array([[[278,  35]],
#
#         [[277,  36]],
#
#         [[276,  37]],
#
#         [[276,  38]],
#
#         [[276,  37]],
#
#         [[277,  36]],
#
#         [[278,  35]],
#
#         [[279,  35]]], dtype=int32), array([[[235,  32]],
#
#         [[234,  33]],
#
#         [[234,  34]],
#
#         [[234,  33]],
#
#         [[235,  32]],
#
#         [[236,  33]],
#
#         [[236,  34]],
#
#         [[236,  33]]], dtype=int32), array([[[277,  29]],
#
#         [[276,  30]],
#
#         [[275,  31]],
#
#         [[276,  32]],
#
#         [[277,  32]],
#
#         [[278,  32]],
#
#         [[279,  31]],
#
#         [[278,  31]],
#
#         [[277,  32]],
#
#         [[276,  32]],
#
#         [[275,  31]],
#
#         [[276,  30]],
#
#         [[277,  29]],
#
#         [[278,  29]],
#
#         [[279,  29]],
#
#         [[278,  29]]], dtype=int32), array([[[243,  28]],
#
#         [[242,  29]],
#
#         [[243,  30]],
#
#         [[244,  30]],
#
#         [[243,  30]],
#
#         [[242,  29]],
#
#         [[243,  28]],
#
#         [[244,  28]]], dtype=int32), array([[[276,  23]],
#
#         [[275,  24]],
#
#         [[276,  25]],
#
#         [[277,  25]],
#
#         [[276,  25]],
#
#         [[275,  24]],
#
#         [[276,  23]],
#
#         [[277,  23]]], dtype=int32), array([[[271,  15]],
#
#         [[270,  16]]], dtype=int32), array([[[270,  13]],
#
#         [[269,  14]],
#
#         [[268,  15]],
#
#         [[268,  16]],
#
#         [[268,  15]],
#
#         [[269,  14]],
#
#         [[270,  13]],
#
#         [[271,  13]]], dtype=int32), array([[[255,  10]],
#
#         [[255,  11]],
#
#         [[255,  12]],
#
#         [[256,  12]],
#
#         [[257,  12]],
#
#         [[257,  11]],
#
#         [[257,  10]],
#
#         [[256,  10]]], dtype=int32), array([[[264,   7]],
#
#         [[263,   8]],
#
#         [[263,   9]],
#
#         [[263,   8]],
#
#         [[264,   7]],
#
#         [[265,   8]],
#
#         [[265,   9]],
#
#         [[265,   8]]], dtype=int32)]

# %%
len(contours)
# Out:
# 456

# %%
cv2.drawContours(img_rgb, contours, -1, (0, 255, 0), 3)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
plt.imshow(img_rgb)

# %% [markdown]
# # Layers of features
# Notice how we can have multiple levels of features:
# - Pixels
# - Gray pixles
# - Threshold pixels
# - Edges
# - Contours
#
# Every level is made of the previous!
#
# Contours are groups of pixels in the edged image
#
# In ALL of the above __we__ designed the features pipeline! This is machine learning. In Deep learning, the choice of features is __learnable__.
